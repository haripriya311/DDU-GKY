# %% [markdown]
# ### import pandas as pd
# ### import numpy as np

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('netflix_titles_2021.csv')
df.head(6)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
#
#            date_added  release_year rating   duration  \
# ...

# %%
df.tail(2)
# Out:
#      show_id   type   title      director  \
# 8805   s8806  Movie    Zoom  Peter Hewitt
# 8806   s8807  Movie  Zubaan   Mozez Singh
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
df.sample(4)
# Out:
#      show_id     type                          title                director  \
# 3907   s3908    Movie  HOMECOMING: A film by Beyoncé  Beyoncé Knowles-Carter
# 4987   s4988    Movie                     Steel Rain           Yang Woo-seok
# 4767   s4768  TV Show             Camarón Revolution                     NaN
# 5248   s5249    Movie                 The Lion Woman            Vibeke Idsøe
#
#                                                    cast          country  \
# 3907                             Beyoncé Knowles-Carter              NaN
# 4987  Woo-sung Jung, Do-won Kwak, Kap-soo Kim, Woo-j...      South Korea
# 4767                     Camarón de la Isla, Juan Diego              NaN
# 5248  Rolf Lassgård, Kjersti Tveterås, Rolf Kristian...  Norway, Germany
#
#            date_added  release_year rating  duration  \
# 3907   April 17, 2019          2019  TV-MA   138 min
# 4987   March 14, 2018          2018  TV-MA   140 min
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.type.value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
df.country.value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
df.loc[2:6]
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
#
#                         director  \
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
#
#                                                 cast country  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 3                                                NaN     NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...     NaN
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...     NaN
#
#            date_added  release_year rating   duration  \
# ...

# %%
 df.value_counts()
# Out:
# show_id  type   title                director             cast                                                                                                                                                                           country                                                 date_added          release_year  rating  duration  listed_in                                         description
# s10      Movie  The Starling         Theodore Melfi       Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor         United States                                           September 24, 2021  2021          PG-13   104 min   Comedies, Dramas                                  A woman adjusting to life after a loss contends with a feisty bird that's taken over her garden — and a husband who's struggling to find a way forward.     1
# ...

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...
